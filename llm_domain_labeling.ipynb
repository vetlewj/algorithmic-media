# %% [markdown]
# This notebook will look at the domains that are present in the reddit dataset and classify those as either
# - 0 scam or irrelevant domain (e.g. bit.ly, goo.gl, etc)
# - 1 generic social media domain (youtube, twitter, facebook, pinterest, instagram, etc)
# - 2 relevant news site (nytimes, wsj, cnn, phys, etc)
# - 3 science repository (direct link to paper like doi, arxiv, pubmed, etc)
#
# It will therefore use gpt-4o-mini to classify the domains.

# %%
import os
from enum import Enum

import pandas as pd
from IPython.core.debugger import prompt
from tqdm import tqdm
import numpy as np
from openai import OpenAI
import json
import seaborn as sns

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
df = pd.read_csv("./data/evaluate r_science post quality - domains.csv")
df.head()
# Out:
#            domain  label  count  relative_proportion    cumsum
# 0     youtube.com    0.0  12970             0.046810  0.046810
# 1      nature.com    1.0  10332             0.037290  0.084100
# 2  eurekalert.org    2.0   6527             0.023557  0.107657
# 3        youtu.be    0.0   5211             0.018807  0.126464
# 4    self.science    0.0   4001             0.014440  0.140904

# %%
# enum of the labels
class DomainLabel(Enum):
    UNLABELED = "unlabeled"
    FAILED = "failed"
    LESS_THAN_2 = "less_than_2"
    UNKNOWN = "unknown"
    SCAM = "scam"
    SOCIAL_MEDIA = "social_media"
    NEWS = "news"
    SCIENCE = "scientific"
    REPO = "repo"
    INDECISIVE = "indecisive"
labels = {
    DomainLabel.UNLABELED.value: -99,
    DomainLabel.FAILED.value: -98,
    DomainLabel.LESS_THAN_2.value: -2,
    DomainLabel.UNKNOWN.value: -1,
    DomainLabel.SCAM.value: 0,
    DomainLabel.SOCIAL_MEDIA.value: 1,
    DomainLabel.NEWS.value: 2,
    DomainLabel.SCIENCE.value: 3,
    DomainLabel.REPO.value: 4,
    DomainLabel.INDECISIVE.value: -3
}

# %%
# stripping the domain to the last two parts 
# Ended up not using it, as this would remove the subdomain, which might be important for the classification
# Furthermore, this could introduce further complications in downstream tasks
def strip(x:str):
    split = x.split(".")
    if len(split) <= 2:
        return x
    if split[0] in ["www", "m", "i", "l", "mobile", "link"] or split[0] == "" or len(split[0]) == 1:
        split = split[1:]
    return ".".join(split)

df['domain_stripped'] = df['domain'].apply(strip)

# %%
df[df["domain_stripped"] != df["domain"]]["domain"]
# Out:
# 30       link.springer.com
# 136          m.youtube.com
# 184             m.phys.org
# 267            i.imgur.com
# 392             m.pnas.org
#                ...
# 30276       i.makeagif.com
# 30277        i.insider.com
# 30278           i.imgtc.ws
# 30279        i.ebayimg.com
# 30280         i.chzbgr.com
# Name: domain, Length: 212, dtype: object

# %%
prompt = f"""
Please classify the following domains as either:
"scam":  scam or irrelevant domain (e.g. bit.ly, goo.gl, etc)
"social_media": generic social media domain (youtube, twitter, facebook, pinterest, instagram, etc)
"news": relevant news site (nytimes, wsj, cnn, phys, etc)
"scientific": relevant science site (sciencedaily, phys, nature, etc) and university sites ending in .edu that are not repositories fall under this category
"repo": science repository (direct link to paper like doi, arxiv, pubmed, etc)
"unknown": if unsure, please classify as "unknown".
The output should be a dictionary with the domain as key and the rating as value, like the following:
{{
    "bit.ly": "scam",
    "youtube.com": "social_media",
    "nytimes.com": "news",
    "sciencedaily.com": "scientific",
    "doi.org": "repo",
     }}
Please stick exactly to the labels provided above. If you are unsure, please classify as "unknown".
"""

# %%
def classify_domains(domains: list, client: OpenAI, i: int) -> list:
    for tries in range(3): 
        response = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": prompt
                },
                {"role": "user",
                 "content": f"Domains: {str(domains)}",
                 },
            ],
            model="gpt-4o-mini",
            temperature=0.0,
        )
        output = response.choices[0].message.content
        dictio = json.loads(output)
        failed = False
        for domain in domains:
            if domain not in dictio or dictio[domain] not in [label.value for label in DomainLabel]:
                print("Failed to get a valid response from the model for i = ", i, " and domain: ", domain)
                failed = True
                continue
        if not failed:
            return [dictio[domain] for domain in domains]
    print("Failed to get a valid response from the model for i = ", i, " and domains: ", domains, " with response: ", dictio)
    return [DomainLabel.FAILED.value]*len(domains)

# %%
# Init the column which will be used to classify the domains with Unlabeled
column_name = "domain_rating_2"
if column_name not in df.columns:
    df[column_name] = DomainLabel.UNLABELED.value
else: 
    print("Column already present")
    
# If the domain has only one occurrence, we can classify it directly as less than 2
df.loc[df["count"] <= 1, column_name] = DomainLabel.LESS_THAN_2.value 
left_over = len(df["domain"]) - len(df[df[column_name] == DomainLabel.LESS_THAN_2.value])
print("Left over to be classified: ", left_over)
# Out:
# Column already present
# Left over to be classified:  11163

# %%
# Loop to classify left over domains
context = 2
for i in tqdm(range(0, left_over, context)):
    if bool(df[column_name].iloc[i] == DomainLabel.UNLABELED.value) or bool(df[column_name].iloc[i] == DomainLabel.FAILED.value):
        domains = df["domain"].iloc[i:i+context].tolist()
        ratings = classify_domains(domains, client, i)
        df.loc[i:i+context -1, column_name] = ratings
    #else:
        #print("Skipping ", i, " as it is already classified")
df.loc[df["count"] <= 1, column_name] = DomainLabel.LESS_THAN_2.value # reclassify the less than 2 might be overwritten
df[column_name].value_counts()
# Out:
# 100%|██████████| 5582/5582 [00:05<00:00, 1105.01it/s]
# domain_rating_2
# less_than_2     19196
# unknown          4490
# scam             2898
# scientific       1673
# news             1411
# repo              535
# social_media      156
# Name: count, dtype: int64

# %%
# In case of failures, first retry with smaller context size (need to be devider of 50)
# If a domain continues to be classified as failed, we can classify it manually
#df.loc[df["domain"] == "tamilastronomy.in", column_name] = DomainLabel.SCAM.value
#df.loc[df["domain"] == "newswire.ca", column_name] = DomainLabel.NEWS.value
df[column_name].value_counts()
df.head(25)
# Out:
#     Unnamed: 0                   domain  label  count  relative_proportion  \
# 0            0              youtube.com    0.0  12970             0.046810
# 1            1               nature.com    1.0  10332             0.037290
# 2            2           eurekalert.org    2.0   6527             0.023557
# 3            3                 youtu.be    0.0   5211             0.018807
# 4            4             self.science    0.0   4001             0.014440
# 5            5        sciencedirect.com    1.0   3737             0.013487
# 6            6         sciencedaily.com    2.0   3317             0.011971
# 7            7              psypost.org    2.0   3253             0.011741
# 8            8                 phys.org    2.0   3169             0.011437
# 9            9          theguardian.com    2.0   3085             0.011134
# 10          10          bioengineer.org    2.0   2622             0.009463
# 11          11            pinterest.com    0.0   2480             0.008951
# 12          12                  bbc.com    2.0   2354             0.008496
# 13          13         sciencealert.com    2.0   2141             0.007727
# 14          14                 pnas.org    1.0   2071             0.007475
# 15          15          sciencenews.org    2.0   2070             0.007471
# 16          16  onlinelibrary.wiley.com    1.0   1961             0.007078
# 17          17              nytimes.com    2.0   1960             0.007074
# 18          18           sciencemag.org    2.0   1870             0.006749
# 19          19         newscientist.com    2.0   1661             0.005995
# 20          20         ncbi.nlm.nih.gov    1.0   1567             0.005656
# 21          21        journals.plos.org    1.0   1559             0.005627
# 22          22                 cell.com    1.0   1514             0.005464
# 23          23   science.sciencemag.org    3.0   1507             0.005439
# 24          24              inverse.com    2.0   1463             0.005280
#
#       cumsum domain_rating_0 domain_rating_1 domain_rating_2
# 0   0.046810    social_media    social_media    social_media
# 1   0.084100      scientific      scientific      scientific
# 2   0.107657            news            news            news
# 3   0.126464    social_media    social_media    social_media
# 4   0.140904         unknown         unknown         unknown
# 5   0.154391      scientific      scientific      scientific
# 6   0.166363      scientific      scientific      scientific
# 7   0.178103            news            news            news
# 8   0.189541      scientific      scientific      scientific
# 9   0.200675            news            news            news
# 10  0.210138         unknown         unknown         unknown
# 11  0.219089    social_media    social_media    social_media
# 12  0.227585            news            news            news
# 13  0.235312            news            news            news
# 14  0.242786      scientific      scientific      scientific
# 15  0.250257            news            news            news
# 16  0.257335      scientific      scientific      scientific
# 17  0.264409            news            news            news
# 18  0.271158      scientific      scientific      scientific
# 19  0.277152            news            news            news
# 20  0.282808            repo            repo            repo
# 21  0.288435      scientific      scientific      scientific
# 22  0.293899      scientific      scientific      scientific
# 23  0.299338      scientific      scientific      scientific
# 24  0.304618            news            news            news

# %%
# voting mechanism to get the final classification
# If all are different classify as indecisive

df["label_voting_lm"] = df[["domain_rating_0", "domain_rating_1", "domain_rating_2"]].mode(axis=1)[0]
df.loc[(df["domain_rating_0"] != df["domain_rating_1"]) & (df["domain_rating_0"] != df["domain_rating_2"]) & (df["domain_rating_1"] != df["domain_rating_2"]), "label_voting_lm"] = DomainLabel.INDECISIVE.value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/UCB/algorithmic-media/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(100, 125, None), ['domain', 'label', 'count', 'domain_rating_0', 'domain_rating_1', 'domain_rating_2', 'label_voting_lm'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[17], line 6
#       4 df["label_voting_lm"] = df[["domain_rating_0", "domain_rating_1", "domain_rating_2"]].mode(axis=1)[0]
#       5 df.loc[(df["domain_rating_0"] != df["domain_rating_1"]) & (df["domain_rating_0"] != df["domain_rating_2"]) & (df["domain_rating_1"] != df["domain_rating_2"]), "label_voting_lm"] = DomainLabel.INDECISIVE.value
# ----> 6 df[100:125, ["domain", "label", "count", "domain_rating_0", "domain_rating_1", "domain_rating_2", "label_voting_lm"]]
#
# File ~/UCB/algorithmic-media/venv/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/UCB/algorithmic-media/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3817, in Index.get_loc(self, key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File ~/UCB/algorithmic-media/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6059, in Index._check_indexing_error(self, key)
#    6055 def _check_indexing_error(self, key):
#    6056     if not is_scalar(key):
#    6057         # if key is not a scalar, directly raise an error (the code below
#    6058         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(100, 125, None), ['domain', 'label', 'count', 'domain_rating_0', 'domain_rating_1', 'domain_rating_2', 'label_voting_lm'])

# %%
#df.loc[100:125, ["domain", "label", "count", "domain_rating_0", "domain_rating_1", "domain_rating_2", "label_voting_lm"]]
df["domain_rating_0"].value_counts(), df["domain_rating_1"].value_counts(), df["domain_rating_2"].value_counts()
# Out:
# (domain_rating_0
#  less_than_2     19196
#  unknown          4431
#  scam             2972
#  scientific       1666
#  news             1408
#  repo              531
#  social_media      155
#  Name: count, dtype: int64,
#  domain_rating_1
#  less_than_2     19196
#  unknown          4486
#  scam             2918
#  scientific       1646
#  news             1414
#  repo              544
#  social_media      155
#  Name: count, dtype: int64,
#  domain_rating_2
#  less_than_2     19196
#  unknown          4490
#  scam             2898
#  scientific       1673
#  news             1411
#  repo              535
#  social_media      156
#  Name: count, dtype: int64)

# %%
# Don't forget to save the file!
df.to_csv("./data/evaluate r_science post quality - domains_lm labeled.csv", index=True)

# %% [markdown]
# # Evaluation

# %%
df[df["label"] == 0][["domain", "label", "domain_rating_0"]]
# Out:
#                                         domain  label domain_rating_0
# 0                                  youtube.com    0.0    social_media
# 3                                     youtu.be    0.0    social_media
# 4                                 self.science    0.0         unknown
# 11                               pinterest.com    0.0    social_media
# 31                             mightyviral.com    0.0            scam
# 35                                  reddit.com    0.0    social_media
# 36                              moviesdost.com    0.0            scam
# 41                                   hit2k.com    0.0            scam
# 49                                  google.com    0.0            scam
# 54                                 hiwebex.com    0.0            scam
# 55                                  medium.com    0.0         unknown
# 67                              ibtimes.com.au    0.0            news
# 70                             docs.google.com    0.0            scam
# 72                                 twitter.com    0.0    social_media
# 79                                facebook.com    0.0    social_media
# 85                                 vitasave.ca    0.0            scam
# 88                                      mta.sa    0.0         unknown
# 100                                   nasa.gov    0.0      scientific
# 104               blog.ebulkemailmarketing.com    0.0            scam
# 112                                  imgur.com    0.0    social_media
# 113                            chinavasion.com    0.0            scam
# 118                               a2zcrack.com    0.0            scam
# 119                      marketsandmarkets.com    0.0            scam
# 122                              irantahgig.ir    0.0         unknown
# 128                            scienceworld.in    0.0         unknown
# 129                 elgibbortechandconsult.com    0.0            scam
# 133                                  forms.gle    0.0            scam
# 136                              m.youtube.com    0.0    social_media
# 144  relationshipengineeringblog.wordpress.com    0.0         unknown
# 145                                 exneto.com    0.0            scam
# 148                           sites.google.com    0.0            scam
# 158                         mystylet-shirt.com    0.0            scam
# 162                             icoachmath.com    0.0         unknown
# 175                           en.wikipedia.org    0.0         unknown
# 176                          reviewscholar.com    0.0         unknown
# 177           popularsciencetoday.blogspot.com    0.0         unknown
# 180                              narvanmag.com    0.0         unknown
# 183         gangsterdynamicsblog.wordpress.com    0.0         unknown
# 189                                 negaco.com    0.0            scam
# 191                                 crbtech.in    0.0            scam
# 192                               linkedin.com    0.0    social_media
# 202                        bestquality4all.com    0.0            scam
# 332                            play.google.com    0.0         unknown
# 333                           99accounting.com    0.0            scam
# 335                             crackithub.com    0.0            scam

# %%
df[df["label"] == 1][["domain", "label", "domain_rating_0"]]
# Out:
#                               domain  label domain_rating_0
# 1                         nature.com    1.0      scientific
# 5                  sciencedirect.com    1.0      scientific
# 14                          pnas.org    1.0      scientific
# 16           onlinelibrary.wiley.com    1.0      scientific
# 20                  ncbi.nlm.nih.gov    1.0            repo
# 21                 journals.plos.org    1.0      scientific
# 22                          cell.com    1.0      scientific
# 26                  academic.oup.com    1.0      scientific
# 28                   jamanetwork.com    1.0      scientific
# 29                           doi.org    1.0            repo
# 30                 link.springer.com    1.0      scientific
# 34              journals.sagepub.com    1.0      scientific
# 37                  researchgate.net    1.0            repo
# 38           advances.sciencemag.org    1.0            repo
# 45                          mdpi.com    1.0      scientific
# 46                     thelancet.com    1.0      scientific
# 53                   frontiersin.org    1.0            repo
# 57                   tandfonline.com    1.0            repo
# 58                      pubs.acs.org    1.0            repo
# 64                         arxiv.org    1.0            repo
# 66           pubmed.ncbi.nlm.nih.gov    1.0            repo
# 92                           bmj.com    1.0            repo
# 94     symbiosisonlinepublishing.com    1.0            repo
# 101                 journals.aps.org    1.0            repo
# 102                elifesciences.org    1.0            repo
# 106               iopscience.iop.org    1.0            repo
# 107                       dx.doi.org    1.0            repo
# 115       royalsocietypublishing.org    1.0            repo
# 127                      biorxiv.org    1.0            repo
# 139                  psycnet.apa.org    1.0            repo
# 178               stm.sciencemag.org    1.0            repo
# 182  agupubs.onlinelibrary.wiley.com    1.0            repo
# 190                 journals.lww.com    1.0            repo
# 194                      medrxiv.org    1.0            repo

# %%
print(df[df["label"] == 2]["domain_rating_0"].value_counts()) 
df[df["label"] == 3][["domain", "label", "domain_rating_0"]]
# Out:
# domain_rating_0
# news          83
# scientific    23
# unknown        9
# scam           3
# Name: count, dtype: int64
#                      domain  label domain_rating_0
# 23   science.sciencemag.org    3.0            repo
# 51              science.org    3.0      scientific
# 61                 nejm.org    3.0            repo
# 116                 cdc.gov    3.0      scientific
# 168              aeaweb.org    3.0      scientific

# %%
df[["domain", "label", "domain_rating_0", "domain_rating_1", "domain_rating_2"]].
# Out:
#                        domain  label domain_rating_0 domain_rating_1  \
# 0                 youtube.com    0.0    social_media    social_media
# 1                  nature.com    1.0      scientific      scientific
# 2              eurekalert.org    2.0      scientific            news
# 3                    youtu.be    0.0    social_media    social_media
# 4                self.science    0.0         unknown         unknown
# ...                       ...    ...             ...             ...
# 30354              hydromo.in    NaN     less_than_2     less_than_2
# 30355  hydrogenwatermaker.net    NaN     less_than_2     less_than_2
# 30356       hydrogengirls.com    NaN     less_than_2     less_than_2
# 30357    hydrogen-central.com    NaN     less_than_2     less_than_2
# 30358             zzsykes.com    NaN     less_than_2     less_than_2
#
#       domain_rating_2
# 0        social_media
# 1          scientific
# 2                news
# 3        social_media
# 4             unknown
# ...               ...
# 30354     less_than_2
# 30355     less_than_2
# 30356     less_than_2
# 30357     less_than_2
# 30358     less_than_2
#
# [30359 rows x 5 columns]

# %%
# Evaluate how consistent the ratings of chat are
df[~(df["domain_rating_0"] == df["domain_rating_1"] == df["domain_rating_2"])][df["domain_rating_2"] != DomainLabel.UNLABELED.value][["domain", "label", "count", "domain_rating_0", "domain_rating_1", "domain_rating_2"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mj/c1h2qjbd7xxbxxm05x_mmd580000gn/T/ipykernel_20532/2462371735.py in ?()
#       1 # Evaluate how consistent the ratings of chat are
# ----> 2 df[~(df["domain_rating_0"] == df["domain_rating_1"] == df["domain_rating_2"])][df["domain_rating_2"] != DomainLabel.UNLABELED.value][["domain", "label", "count", "domain_rating_0", "domain_rating_1", "domain_rating_2"]]
#
# ~/UCB/algorithmic-media/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# get all rows that are not identical in row domain_rating_0 and domain_rating_1 and domain_rating_2
df[(df['domain_rating_0'] != df['domain_rating_1']) |
                 (df['domain_rating_0'] != df['domain_rating_2']) |
                 (df['domain_rating_1'] != df['domain_rating_2'])][df["domain_rating_2"] != DomainLabel.UNLABELED.value][["domain", "label", "count", "domain_rating_0", "domain_rating_1", "domain_rating_2"]]
# Out:
# /var/folders/mj/c1h2qjbd7xxbxxm05x_mmd580000gn/T/ipykernel_20532/3534691693.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df['domain_rating_0'] != df['domain_rating_1']) |
#                                         domain  label  count domain_rating_0  \
# 2                               eurekalert.org    2.0   6527      scientific
# 21                           journals.plos.org    1.0   1559      scientific
# 23                      science.sciencemag.org    3.0   1507            repo
# 28                             jamanetwork.com    1.0   1255      scientific
# 37                            researchgate.net    1.0    969            repo
# 38                     advances.sciencemag.org    1.0    965            repo
# 93                            scitechdaily.com    2.0    394      scientific
# 144  relationshipengineeringblog.wordpress.com    0.0    241         unknown
# 153                               yacinews.com    2.0    221            scam
# 206                       collective-spark.xyz    NaN    158         unknown
# 209                            ahajournals.org    NaN    154            repo
# 214                      journals.uchicago.edu    NaN    151            repo
# 216                             massivesci.com    NaN    150            news
# 219                      directorsblog.nih.gov    NaN    147         unknown
# 220                                 apple.news    NaN    147         unknown
# 225                                    msn.com    NaN    144         unknown
# 226                           news-medical.net    NaN    143            news
# 246                            carbonbrief.org    NaN    128            news
# 251                                  niume.com    NaN    126         unknown
# 253                          biologychamps.com    NaN    125         unknown
# 263                               redorbit.com    NaN    120         unknown
# 268                          news.illinois.edu    NaN    117            news
# 269     spiritualengineeringsite.wordpress.com    NaN    117         unknown
# 270                       blog.frontiersin.org    NaN    117         unknown
# 274                           msutoday.msu.edu    NaN    114            news
# 275                              blog.pnas.org    NaN    114         unknown
# 276                    apitherapy.blogspot.com    NaN    113         unknown
# 277                               appsbazar.in    NaN    112         unknown
# 278                    cannabissciencetech.com    NaN    112         unknown
# 281                         psychnewsdaily.com    NaN    111         unknown
# 282                                 scidoc.org    NaN    111         unknown
# 287                           sciencetimes.com    NaN    109         unknown
# 288                             justscience.in    NaN    108         unknown
# 289                sreysofficial.wordpress.com    NaN    108         unknown
# 290                         newsroom.heart.org    NaN    108            news
# 293                            howpeopledo.com    NaN    107         unknown
# 299                            behaviorist.biz    NaN    104         unknown
# 304                             saludmovil.com    NaN    103         unknown
# 308                                    aan.com    NaN    103      scientific
# 329                     absolute-relativity.eu    NaN     93         unknown
#
#     domain_rating_1 domain_rating_2
# 2              news            news
# 21       scientific            repo
# 23       scientific            repo
# 28       scientific            news
# 37          unknown         unknown
# 38       scientific            repo
# 93             news      scientific
# 144            scam            scam
# 153         unknown         unknown
# 206            scam            scam
# 209      scientific      scientific
# 214      scientific      scientific
# 216      scientific      scientific
# 219      scientific      scientific
# 220            news            news
# 225            scam            news
# 226            news      scientific
# 246            news      scientific
# 251            scam            scam
# 253            scam            scam
# 263            news            news
# 268      scientific            news
# 269            scam            scam
# 270      scientific      scientific
# 274      scientific            news
# 275      scientific      scientific
# 276            scam            scam
# 277            scam            scam
# 278      scientific      scientific
# 281            news            news
# 282            scam            scam
# 287            news            news
# 288            scam            scam
# 289            scam            scam
# 290      scientific            news
# 293            scam            scam
# 299            scam            scam
# 304            scam         unknown
# 308         unknown         unknown
# 329            scam         unknown
