# %% [markdown]
# # Notebook to try to get identifiers directly from links that can be used in the Semantic Scholar APIs to get the abstracts of the papers.
#
# Note: This requires the combined_for_analysis_sensationalism_jargon_categories_domain_labels.csv file to be in the data folder. This file can be copied form the projects google drive folder.
#
# ### Data that can be used to get details of a paper from the semantic scholar API:
#
# URLS:
#
# - semanticscholar.org
# - arxiv.org
# - aclweb.org
# - acm.org
# - biorxiv.org
#
# ID:
#
# - DOI
# - Microsoft Academic Graph
# - Association for Computational Linguistics
# - PubMed/Medline
# - PubMed Central

# %%
import pandas as pd

# %%
inp_df = pd.read_csv('../data/combined_for_analysis_sensationalism_jargon_categories_domain_labels .csv')
inp_df.head()
# Out:
#    Unnamed: 0  year  month                                              title  \
# 0           0  2018      3  The Bradford pear has created an ecological ni...
# 1           1  2018      3  Astronomers say they've discovered evidence of...
# 2           2  2018      3  The first detection of 21 cm signal from hydro...
# 3           3  2018      3    Universe's First Stars Detected? Get the Facts.
# 4           4  2018      3  Simple telescope picks up hint of the Universe...
#
#   link_flair_text                       domain  score  num_comments  \
# 0         Biology         greenvilleonline.com      2             4
# 1       Astronomy                    aftau.org     46            11
# 2       Astronomy                 news.mit.edu      1             0
# 3       Astronomy  news.nationalgeographic.com      1             1
# 4       Astronomy              arstechnica.com      3             2
#
#    sensationalism_score  jargon_proportion  ... is_top_domain_social_media  \
# 0              0.533427           0.181818  ...                      False
# 1              0.511129           0.068966  ...                      False
# 2              0.412405           0.083333  ...                      False
# 3              0.561694           0.000000  ...                      False
# 4              0.492255           0.333333  ...                      False
#
#   is_top_domain_scientific  is_top_domain_news  is_top_domain_repo  \
# 0                    False               False               False
# 1                    False               False               False
# 2                    False               False               False
# 3                    False               False               False
# 4                    False               False               False
#
#    is_top_domain_scam  is_top_domain_unknown  is_top_domain_indecisive  \
# 0               False                  False                     False
# 1               False                  False                     False
# 2               False                  False                     False
# 3               False                  False                     False
# 4               False                  False                     False
#
#    is_top_domain_less_than_2  label_voting_lm  label_voting_manual
# 0                      False      less_than_2          less_than_2
# 1                      False       scientific           scientific
# 2                      False             news                 news
# 3                      False             news                 news
# 4                      False             news                 news
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Most common domains
#
# We only want to get the identifiers for the most common domains in the dataset so that we can justify the bias in our sample. Getting the identifiers for all the domains would give us a biased result, but it would be harder to identify/justify the bias. Hence, we will only select the top domains from scientific, news and repo categories.

# %%
# Most common labels in scientific:
most_common_scientific = ['nature.com', 'sciencedirect.com', 'sciencedaily.com', 'phys.org', 'bioengineer.org', 'pnas.org', 'onlinelibrary.wiley.com', 'sciencemag.org', 'journals.plos.org', 'cell.com']
# Most common labels in news:
most_common_news = ['eurekalert.org', 'psypost.org', 'theguardian.com', 'bbc.com', 'sciencealert.com', 'sciencenews.org', 'nytimes.com', 'newscientist.com', 'inverse.com', 'livescience.com']
# Most common labels in repo:
most_common_repos = ['ncbi.nlm.nih.gov', 'doi.org', 'frontiersin.org', 'tandfonline.com', 'pubs.acs.org', 'nejm.org', 'arxiv.org', 'pubmed.ncbi.nlm.nih.gov', 'bmj.com', 'symbiosisonlinepublishing.com']

# %%
# Filter the data to only include the most common domains from scientific, news and repo categories
inp_df = inp_df[inp_df['domain'].isin(most_common_scientific + most_common_news + most_common_repos)]
print(f"Number of rows in the filtered data: {inp_df.shape[0]}")
inp_df.head()
# Out:
# Number of rows in the filtered data: 56507
#     Unnamed: 0  year  month  \
# 5            5  2018      3
# 7            7  2018      3
# 8            8  2018      3
# 17          17  2018      3
# 19          19  2018      3
#
#                                                 title link_flair_text  \
# 5   Firearm Injuries Drop 20 Percent When Gun Owne...         Biology
# 7   An Even-Weirder-Than-Usual Tardigrade Just Tur...         Biology
# 8      This Woman Is Her Own Twin: What Is Chimerism?         Biology
# 17  Biodiversity loss raises risk of 'extinction c...         Biology
# 19  Supplementation with probiotics during late pr...          Health
#
#                domain  score  num_comments  sensationalism_score  \
# 5            nejm.org     84            22              0.530595
# 7     livescience.com     23             5              0.545099
# 8     livescience.com      1             1              0.601028
# 17   sciencedaily.com      1             1              0.517565
# 19  journals.plos.org      8             1              0.482136
#
#     jargon_proportion  ... is_top_domain_social_media  \
# 5            0.000000  ...                      False
# 7            0.000000  ...                      False
# 8            0.000000  ...                      False
# 17           0.142857  ...                      False
# 19           0.314286  ...                      False
#
#    is_top_domain_scientific  is_top_domain_news  is_top_domain_repo  \
# 5                     False               False                True
# 7                     False                True               False
# 8                     False                True               False
# 17                     True               False               False
# 19                     True               False               False
#
#     is_top_domain_scam  is_top_domain_unknown  is_top_domain_indecisive  \
# 5                False                  False                     False
# 7                False                  False                     False
# 8                False                  False                     False
# 17               False                  False                     False
# 19               False                  False                     False
#
#     is_top_domain_less_than_2  label_voting_lm  label_voting_manual
# 5                       False             repo                 repo
# 7                       False             news                 news
# 8                       False             news                 news
# 17                      False       scientific           scientific
# 19                      False       scientific           scientific
#
# [5 rows x 22 columns]

# %%
"""
The following types of IDs are supported: # from https://api.semanticscholar.org/api-docs/#tag/Paper-Data/operation/get_graph_get_paper

<sha> - a Semantic Scholar ID, e.g. 649def34f8be52c8b66281af98ae884c09aef38b
CorpusId:<id> - a Semantic Scholar numerical ID, e.g. CorpusId:215416146
DOI:<doi> - a Digital Object Identifier, e.g. DOI:10.18653/v1/N18-3011
ARXIV:<id> - arXiv.rg, e.g. ARXIV:2106.15928
MAG:<id> - Microsoft Academic Graph, e.g. MAG:112218234
ACL:<id> - Association for Computational Linguistics, e.g. ACL:W12-3903
PMID:<id> - PubMed/Medline, e.g. PMID:19872477
PMCID:<id> - PubMed Central, e.g. PMCID:2323736
URL:<url> - URL from one of the sites listed below, e.g. URL:https://arxiv.org/abs/2106.15928v1
"""
identifiers_semantic_scholar = {
    'DOI': 'DOI',
    'Microsoft Academic Graph': 'MAG',
    'Association for Computational Linguistics': 'ACL',
    'PubMed / Medline': 'PMID',
    'PubMed Central': 'PMCID',
    'URL': 'URL',
    'arXiv': 'ARXIV',
    'Semantic Scholar': 'sha',
    'Semantic Scholar ID': 'CorpusId',
}

# %%
import re

# %%
# Get all doi from links
# Help from ChatGPT to get the patterns right and verified (testing with a few examples) with regex101.com
doi_patterns = [
            r'10\.\d{4,9}/[-._;()/:A-Z0-9]+' ,
            r'10\.\d{4,9}/[-._;()/:\w]+',
            r'doi:\s*(10\.\d{4,9}/[-._;()/:\w]+)',
            r'doi\.org/(10\.\d{4,9}/[-._;()/:\w]+)'
]

def get_doi_from_link(link):
    for pattern in doi_patterns:
        doi = re.search(pattern, link, re.IGNORECASE)
        if doi:
            doi_group = doi.group()
            if doi_group.endswith('/full'):
                return doi_group[:-5]
            return doi_group
    return None

inp_df['doi'] = inp_df['url'].apply(get_doi_from_link)

print(f"Number of DOIs: {inp_df['doi'].notnull().sum()}")
inp_df.head()
# Out:
# Number of DOIs: 6974
#     Unnamed: 0  year  month  \
# 5            5  2018      3
# 7            7  2018      3
# 8            8  2018      3
# 17          17  2018      3
# 19          19  2018      3
#
#                                                 title link_flair_text  \
# 5   Firearm Injuries Drop 20 Percent When Gun Owne...         Biology
# 7   An Even-Weirder-Than-Usual Tardigrade Just Tur...         Biology
# 8      This Woman Is Her Own Twin: What Is Chimerism?         Biology
# 17  Biodiversity loss raises risk of 'extinction c...         Biology
# 19  Supplementation with probiotics during late pr...          Health
#
#                domain  score  num_comments  sensationalism_score  \
# 5            nejm.org     84            22              0.530595
# 7     livescience.com     23             5              0.545099
# 8     livescience.com      1             1              0.601028
# 17   sciencedaily.com      1             1              0.517565
# 19  journals.plos.org      8             1              0.482136
#
#     jargon_proportion  ... is_top_domain_scientific is_top_domain_news  \
# 5            0.000000  ...                    False              False
# 7            0.000000  ...                    False               True
# 8            0.000000  ...                    False               True
# 17           0.142857  ...                     True              False
# 19           0.314286  ...                     True              False
#
#     is_top_domain_repo  is_top_domain_scam  is_top_domain_unknown  \
# 5                 True               False                  False
# 7                False               False                  False
# 8                False               False                  False
# 17               False               False                  False
# 19               False               False                  False
#
#     is_top_domain_indecisive  is_top_domain_less_than_2  label_voting_lm  \
# 5                      False                      False             repo
# 7                      False                      False             news
# 8                      False                      False             news
# 17                     False                      False       scientific
# 19                     False                      False       scientific
#
#     label_voting_manual                           doi
# 5                  repo          10.1056/NEJMc1712773
# 7                  news                          None
# 8                  news                          None
# 17           scientific                          None
# 19           scientific  10.1371/journal.pmed.1002507
#
# [5 rows x 23 columns]

# %%
# get all PMID and PMCID from links
# Help from ChatGPT to get the patterns right and verified (testing with a few examples) with regex101.com

# PMID: example looks like this : https://pubmed.ncbi.nlm.nih.gov/22110403/ where 22110403 is the PMID
# it can also look like this: https://pubmed.ncbi.nlm.nih.gov/35964870/
pmid_pattern = r'pmid=(\d+)|pubmed(?:\/|%2F)(\d+)|pubmed\.ncbi\.nlm\.nih\.gov\/(\d+)\/?' 
# PMCID: example looks like this : https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5793096/#__ffn_sectitle where PMC5793096 is the PMCID
pmcid_pattern = r'https?:\/\/www\.ncbi\.nlm\.nih\.gov\/(?:labs\/)?pmc\/articles\/(PMC\d+)\/?'

def get_pmid_from_link(link):
    pmid = re.search(pmid_pattern, link, re.IGNORECASE)
    if pmid:
        return next(filter(None, pmid.groups()))
    return None

def get_pmcid_from_link(link):
    pmcid = re.search(pmcid_pattern, link, re.IGNORECASE)
    if pmcid:
        full_pmcid = pmcid.group(1)
        return full_pmcid[3:] if full_pmcid.startswith('PMC') else full_pmcid
    return None

inp_df['pmid'] = inp_df['url'].apply(get_pmid_from_link)
inp_df['pmcid'] = inp_df['url'].apply(get_pmcid_from_link)

print(f"Number of PMIDs: {inp_df['pmid'].notnull().sum()}")
print(f"Number of PMCIDs: {inp_df['pmcid'].notnull().sum()}")
# Out:
# Number of PMIDs: 1109
# Number of PMCIDs: 789

# %%
# Get all ARXIV identifiers from links, if the domain is arxiv.org, then add a column called arxiv that has the url value
inp_df['arxiv'] = inp_df[inp_df['domain'] == 'arxiv.org']['url']

print(f"Number of ARXIVs: {inp_df['arxiv'].notnull().sum()}")
# Out:
# Number of ARXIVs: 483

# %%
"""
Add new column identifier with the prefixes from `identifiers_semantic_scholar` followed by the appropriate identifier value (doi, pmid, pmcid, etc.)
"""
def get_identifier(row):
    if row['doi']:
        return f"{identifiers_semantic_scholar['DOI']}:{row['doi']}"
    if row['pmid']:
        return f"{identifiers_semantic_scholar['PubMed / Medline']}:{row['pmid']}"
    if row['pmcid']:
        return f"{identifiers_semantic_scholar['PubMed Central']}:{row['pmcid']}"
    if row['arxiv']:
        if pd.notna(row['arxiv']):
            return f"{identifiers_semantic_scholar['URL']}:{row['arxiv']}"
    return None

inp_df['identifier'] = inp_df.apply(get_identifier, axis=1)

# %%
out_pf = inp_df[inp_df['identifier'].notnull()]
print(f"Number of rows with identifiers: {out_pf.shape[0]}")
# Out:
# Number of rows with identifiers: 9354

# %%
# Remove the columns that are not needed
out_pf = out_pf.drop(columns=['doi', 'pmid', 'pmcid', 'arxiv'])
out_pf.head()
# Out:
#     Unnamed: 0  year  month  \
# 5            5  2018      3
# 19          19  2018      3
# 25          25  2018      3
# 31          31  2018      3
# 33          33  2018      3
#
#                                                 title link_flair_text  \
# 5   Firearm Injuries Drop 20 Percent When Gun Owne...         Biology
# 19  Supplementation with probiotics during late pr...          Health
# 25  Study finds that bee venom could be a useful p...        Medicine
# 31  The interplay of gene flow, population size va...         Biology
# 33  Undisclosed Conflicts of Interests among Biome...  Social Science
#
#                      domain  score  num_comments  sensationalism_score  \
# 5                  nejm.org     84            22              0.530595
# 19        journals.plos.org      8             1              0.482136
# 25         ncbi.nlm.nih.gov     27             9              0.507827
# 31  onlinelibrary.wiley.com      6             0              0.433548
# 33         ncbi.nlm.nih.gov    263            21              0.511708
#
#     jargon_proportion  ... is_top_domain_scientific is_top_domain_news  \
# 5            0.000000  ...                    False              False
# 19           0.314286  ...                     True              False
# 25           0.333333  ...                    False              False
# 31           0.352941  ...                     True              False
# 33           0.086957  ...                    False              False
#
#     is_top_domain_repo  is_top_domain_scam  is_top_domain_unknown  \
# 5                 True               False                  False
# 19               False               False                  False
# 25                True               False                  False
# 31               False               False                  False
# 33                True               False                  False
#
#     is_top_domain_indecisive  is_top_domain_less_than_2  label_voting_lm  \
# 5                      False                      False             repo
# 19                     False                      False       scientific
# 25                     False                      False             repo
# 31                     False                      False       scientific
# 33                     False                      False             repo
#
#     label_voting_manual                        identifier
# 5                  repo          DOI:10.1056/NEJMc1712773
# 19           scientific  DOI:10.1371/journal.pmed.1002507
# 25                 repo                     PMCID:5793096
# 31           scientific    DOI:10.1111/evo.13435/abstract
# 33                 repo                     PMID:29400625
#
# [5 rows x 23 columns]

# %%
out_pf.to_csv('../data/filtered_data_with_identifiers.csv', index=False)

# %%
inp_df.shape
# Out:
# (56507, 27)

# %%
out_pf.shape
# Out:
# (9354, 23)

# %%
# print the rows that are in inp_df but not in out_pf that have label_voting_manual == repo
remainders_df = inp_df[~inp_df['url'].isin(out_pf['url']) & (inp_df['label_voting_manual'] == 'repo')]
# drop unnecessary columns
remainders_df = remainders_df.drop(columns=['doi', 'pmid', 'pmcid', 'arxiv'])
# drop all is_top_domain rows
remainders_df = remainders_df.drop(columns=['is_top_domain_news', 'is_top_domain_repo', 'is_top_domain_scientific', 'is_top_domain_scam', 'is_top_domain_unknown', 'is_top_domain_indecisive', 'is_top_domain_less_than_2'])
remainders_df
# Out:
#         Unnamed: 0  year  month  \
# 441            441  2018      3
# 442            442  2018      3
# 443            443  2018      3
# 444            444  2018      3
# 445            445  2018      3
# ...            ...   ...    ...
# 195651      195651  2019     10
# 195730      195730  2019     10
# 195846      195846  2019     10
# 195951      195951  2019     10
# 196079      196079  2019     10
#
#                                                     title link_flair_text  \
# 441     Neuromyelitis Optica Spectrum Disorder as a Pa...          Health
# 442     Central Post-stroke Pain and Pharmacological T...          Health
# 443     Atypical McArdle’s disease with asymmetric wea...          Health
# 444     Dynamic F-Wave Study Aids in Diagnosis of Neur...          Health
# 445     Meningioma: The Unusual Growth in a Transsexua...          Health
# ...                                                   ...             ...
# 195651  The production of unnecessary infant &amp; tod...     Environment
# 195730  The production of unnecessary infant and toddl...     Environment
# 195846  Support for breastfeeding is an environmental ...     Environment
# 195951  Current knowledge is insufficient to determine...          Health
# 196079  Bicontinuous porous membranes can be made just...       Chemistry
#
#                                domain  score  num_comments  \
# 441     symbiosisonlinepublishing.com      1             0
# 442     symbiosisonlinepublishing.com      1             0
# 443     symbiosisonlinepublishing.com      1             0
# 444     symbiosisonlinepublishing.com      1             0
# 445     symbiosisonlinepublishing.com      1             0
# ...                               ...    ...           ...
# 195651                        bmj.com      3             6
# 195730                        bmj.com     30            38
# 195846                        bmj.com      1             0
# 195951                        bmj.com      8             4
# 196079                   pubs.acs.org      0             1
#
#         sensationalism_score  jargon_proportion  \
# 441                 0.394180           0.000000
# 442                 0.389311           0.000000
# 443                 0.413239           0.125000
# 444                 0.385285           0.000000
# 445                 0.461184           0.090909
# ...                      ...                ...
# 195651              0.582619           0.205128
# 195730              0.582105           0.205128
# 195846              0.532830           0.428571
# 195951              0.470955           0.238095
# 196079              0.402641           0.266667
#
#                                                       url      id  \
# 441     https://symbiosisonlinepublishing.com/neurolog...  82vivw
# 442     https://symbiosisonlinepublishing.com/neurolog...  82viy3
# 443     https://symbiosisonlinepublishing.com/neurolog...  82vizn
# 444     https://symbiosisonlinepublishing.com/neurolog...  82vj1d
# 445     https://symbiosisonlinepublishing.com/neurolog...  82vj33
# ...                                                   ...     ...
# 195651          https://www.bmj.com/content/367/bmj.l5646  dcyrm2
# 195730          https://www.bmj.com/content/367/bmj.l5646  ddcd5u
# 195846          https://www.bmj.com/content/367/bmj.l5646  deaq7v
# 195951     https://www.bmj.com/content/366/bmj.l5275.long  dewj3w
# 196079              https://pubs.acs.org/toc/cmatex/31/18  dfi0t9
#
#         is_top_domain_social_media label_voting_lm label_voting_manual  \
# 441                          False            repo                repo
# 442                          False            repo                repo
# 443                          False            repo                repo
# 444                          False            repo                repo
# 445                          False            repo                repo
# ...                            ...             ...                 ...
# 195651                       False            repo                repo
# 195730                       False            repo                repo
# 195846                       False            repo                repo
# 195951                       False            repo                repo
# 196079                       False            repo                repo
#
#        identifier
# 441          None
# 442          None
# 443          None
# 444          None
# 445          None
# ...           ...
# 195651       None
# 195730       None
# 195846       None
# 195951       None
# 196079       None
#
# [816 rows x 16 columns]

# %%
# get the count of the domains in remainders_df
remainders_df['domain'].value_counts()
# Out:
# domain
# symbiosisonlinepublishing.com    385
# bmj.com                          379
# ncbi.nlm.nih.gov                  21
# doi.org                           16
# pubs.acs.org                       4
# frontiersin.org                    4
# nejm.org                           3
# tandfonline.com                    2
# pubmed.ncbi.nlm.nih.gov            2
# Name: count, dtype: int64

# %%
remainders_df[remainders_df['domain'] == ('doi.org')]
# Out:
#         Unnamed: 0  year  month  \
# 6694          6694  2021      6
# 8507          8507  2021      6
# 21866        21866  2020     11
# 36360        36360  2021      5
# 63365        63365  2020      8
# 88221        88221  2020      7
# 92983        92983  2018      9
# 92984        92984  2018      9
# 116422      116422  2019      6
# 120563      120563  2021      8
# 133297      133297  2021      4
# 137186      137186  2019      5
# 157535      157535  2020      5
# 159405      159405  2020      5
# 159409      159409  2020      5
# 178065      178065  2022      2
#
#                                                     title link_flair_text  \
# 6694    Autistic adults’ experiences of diagnostic dis...      Psychology
# 8507    Wikipedia articles about women (who meet Wikip...  Social Science
# 21866   In pet rabbits more than 6 years old, the prev...  Animal Science
# 36360   Defining and Measuring Meditation-Related Adve...      Psychology
# 63365   Journalists’ Twitter use shows them talking wi...  Social Science
# 88221   Fighting COVID-19 Misinformation on Social Med...      Psychology
# 92983   Does Rejection Still Hurt? Examining the Effec...  Social Science
# 92984   Examining the Effects of Network Attention and...  Social Science
# 116422  Some patients feel shame, anxiety or fear imme...        Medicine
# 120563  New study finds a high need for uniqueness amo...      Psychology
# 133297  New paper in Psych Science today about how dog...  Animal Science
# 137186  Statins could potentially be treat some trauma...        Medicine
# 157535  Self-esteem and self-concept clarity are signi...      Psychology
# 159405  Analysis of health outcomes in vaccinated and ...          Health
# 159409  Analysis of health outcomes in vaccinated and ...          Health
# 178065  Court-related fees imposed on misdemeanor defe...  Social Science
#
#          domain  score  num_comments  sensationalism_score  jargon_proportion  \
# 6694    doi.org    144            17              0.451307           0.133333
# 8507    doi.org     45             7              0.516609           0.000000
# 21866   doi.org     42             0              0.474504           0.098039
# 36360   doi.org      9             7              0.434813           0.000000
# 63365   doi.org    517            81              0.567829           0.114286
# 88221   doi.org     32            12              0.609591           0.000000
# 92983   doi.org      1             1              0.543843           0.000000
# 92984   doi.org     10             4              0.415058           0.000000
# 116422  doi.org     24            18              0.593809           0.157895
# 120563  doi.org     34            26              0.618210           0.170732
# 133297  doi.org     18             4              0.529235           0.105263
# 137186  doi.org      1             0              0.562478           0.243243
# 157535  doi.org     14             0              0.506308           0.250000
# 159405  doi.org      0             2              0.452458           0.235294
# 159409  doi.org      7            22              0.452458           0.235294
# 178065  doi.org  27263           812              0.538686           0.214286
#
#                                                 url      id  \
# 6694    https://doi.org/10.1177%2F23969415211022955  nsw60m
# 8507    https://doi.org/10.1177%2F14614448211023772  o9mr00
# 21866    https://doi.org/10.1177%2F0300985820973460  jxnmxw
# 36360    https://doi.org/10.1177%2F2167702621996340  nn4csj
# 63365    https://doi.org/10.1177%2F2056305120926639  i4tcau
# 88221    https://doi.org/10.1177%2F0956797620939054  hl5a5z
# 92983    https://doi.org/10.1177%2F0894439318795128  9je2m0
# 92984    https://doi.org/10.1177%2F0894439318795128  9je3en
# 116422   https://doi.org/10.1177%2F0146167219855042  c4pf26
# 120563  https://doi.org/10.1177%2F19485506211031082  p6e8wi
# 133297   https://doi.org/10.1177%2F0956797620979149  mmm6u5
# 137186     https://www.doi.org/jamaneurol.2019.1148  bstccn
# 157535   https://doi.org/10.1177%2F0265407520911131  gi7xsn
# 159405   https://doi.org/10.1177%2F2050312120925344  gtg4u0
# 159409   https://doi.org/10.1177%2F2050312120925344  gtgfgi
# 178065  https://doi.org/10.1177%2F00031224221075783  sz3gv2
#
#         is_top_domain_social_media label_voting_lm label_voting_manual  \
# 6694                         False            repo                repo
# 8507                         False            repo                repo
# 21866                        False            repo                repo
# 36360                        False            repo                repo
# 63365                        False            repo                repo
# 88221                        False            repo                repo
# 92983                        False            repo                repo
# 92984                        False            repo                repo
# 116422                       False            repo                repo
# 120563                       False            repo                repo
# 133297                       False            repo                repo
# 137186                       False            repo                repo
# 157535                       False            repo                repo
# 159405                       False            repo                repo
# 159409                       False            repo                repo
# 178065                       False            repo                repo
#
#        identifier
# 6694         None
# 8507         None
# 21866        None
# 36360        None
# 63365        None
# 88221        None
# 92983        None
# 92984        None
# 116422       None
# 120563       None
# 133297       None
# 137186       None
# 157535       None
# 159405       None
# 159409       None
# 178065       None

# %%
# how many are label_voting_manual == repo
print(out_pf['label_voting_manual'].value_counts())

# in the original file: 
print(inp_df['label_voting_manual'].value_counts())
# Out:
# label_voting_manual
# repo          5909
# scientific    3445
# Name: count, dtype: int64
# label_voting_manual
# scientific    27132
# news          22650
# repo           6725
# Name: count, dtype: int64

# %%
# filter the data so we only have label_voting_manual == repo and write to csv
out_pf[out_pf['label_voting_manual'] == 'repo'].to_csv('../data/filtered_data_with_identifiers_repo.csv', index=False)
